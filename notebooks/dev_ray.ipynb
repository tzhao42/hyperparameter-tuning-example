# %% [markdown]
# # Hyperparameter Tuning with `ray`

# %% [markdown]
# ## Basic training script
#
# Classify images from the CIFAR10 dataset. We look at the effect of batch size, learning rate, and momentum.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms

# %%
DATA_PATH = "/home/tzhao/Workspace/hyperparameter-tuning-example/data"
NUM_EPOCHS = 4
DEVICE = "cpu" # Ray is very picky with resource usage, so we will use cpu to simplify configs

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ## Hyperparameter tuning with `ray`

# %%
from ray import tune
from ray.air import session

# %%
def train_ray_tune(config):

    ###########################################
    ##### RAY TUNE: Initialize parameters #####
    ###########################################
    
    batch_size=config["batch_size"]
    lr=config["lr"]
    momentum=config["momentum"]
    verbose = False
    download = False

    ###########################################
    ###########################################
    ###########################################

    # Load dataset
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    trainset = torchvision.datasets.CIFAR10(root=DATA_PATH, train=True, download=download, transform=transform)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)

    testset = torchvision.datasets.CIFAR10(root=DATA_PATH, train=False, download=download, transform=transform)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

    # Load nn
    net = Net().to(DEVICE)

    # Load loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)
    
    # Train
    for epoch in range(NUM_EPOCHS):
        
        # Train single epoch
        for data in trainloader:
            inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
        
        # Test
        test_loss = 0
        total = 0
        correct = 0
        with torch.no_grad():
            for data in testloader:
                inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
                outputs = net(inputs)

                # Get test loss
                loss = criterion(outputs, labels)
                test_loss += loss.item()

                # Get test acc
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        test_acc = correct / total

        if verbose:
            print(f"Epoch {epoch}: Test loss: {test_loss:.2f}")
            print(f"Epoch {epoch}: Test acc: {test_acc:.2f}")

        #########################################################
        ##### RAY TUNE: Report test loss and handle pruning #####
        #########################################################

        session.report({"test_acc": test_acc})

        #########################################################
        #########################################################
        #########################################################

    if verbose:
        print("Training completed.")
        print(f"Final test loss: {test_loss:.2f}")
        print(f"Final test acc: {test_acc:.2f}")
    
    return {"test_acc" : test_acc}

# %%
search_space = {
    "batch_size" : tune.randint(4,128),
    "lr": tune.loguniform(1e-5, 1e-1),
    "momentum": tune.uniform(0.1, 0.99),
}

tuner = tune.Tuner(
    train_ray_tune,
    tune_config=tune.TuneConfig(
        metric="test_acc",
        mode="max",
        num_samples=-1, # No limit to number of samples
        time_budget_s=300, # Limit time budget to 5 mins
    ),
    param_space=search_space,
)
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-07-21 08:28:48</td></tr>
# <tr><td>Running for: </td><td>00:05:00.53        </td></tr>
# <tr><td>Memory:      </td><td>32.7/125.6 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 48.0/48 CPUs, 0/2 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc               </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  test_acc</th></tr>
# </thead>
# <tbody>
# <tr><td>train_ray_tune_71ab8_00000</td><td>TERMINATED</td><td>10.47.0.57:1134061</td><td style="text-align: right;">           5</td><td style="text-align: right;">0.000471392</td><td style="text-align: right;">  0.559327</td><td style="text-align: right;">     5</td><td style="text-align: right;">        185.959 </td><td style="text-align: right;">    0.4464</td></tr>
><td style="text-align: right;">     5</td><td style="text-align: right;">         98.2722</td><td style="text-align: right;">    0.1222</td></tr>
# <tr><td>train_ray_tune_71ab8_00011</td><td>TERMINATED</td><td>10.47.0.57:1134071</td><td style="text-align: right;">         119</td><td style="text-align: right;">0.000196387</td><td style="text-align: right;">  0.308879</td><td style="text-align: right;">     5</td><td style="text-align: right;">         98.9222</td><td style="text-align: right;">    0.1008</td></tr>
# <tr><td>train_ray_tune_71ab8_00012</td><td>TERMINATED</td><td>10.47.0.57:1134072</td><td style="text-align: right;">         102</td><td style="text-align: right;">2.53128e-05</td><td style="text-align: right;">  0.595633</td><td style="text-align: right;">     5</td><td style="text-align: right;">         99.0928</td><td style="text-align: right;">    0.0967</td></tr>
# <tr><td>train_ray_tune_71ab8_00013</td><td>TERMINATED</td><td>10.47.0.57:1134073</td><td style="text-align: right;">          89</td><td style="text-align: right;">1.41223e-05</td><td style="text-align: right;">  0.109811</td><td style="text-align: right;">     5</td><td style="text-align: right;">         98.7257</td><td style="text-align: right;">    0.1   </td></tr>
# <tr><td>train_ray_tune_71ab8_00014</td><td>TERMINATED</td><td>10.47.0.57:1134074</td><td style="text-align: right;">          30</td><td style="text-align: right;">0.000135417</td><td style="text-align: right;">  0.933281</td><td style="text-align: right;">     5</td><td style="text-align: right;">        112.397 </td><td style="text-align: right;">    0.2539</td></tr>
# <tr><td>train_ray_tune_71ab8_00015</td><td>TERMINATED</td><td>10.47.0.57:1134075</td><td style="text-align: right;">         108</td><td style="text-align: right;">0.000430082</td><td style="text-align: right;">  0.916528</td><td style="text-align: right;">     5</td><td style="text-align: right;">         98.5992</td><td style="text-align: right;">    0.191 </td></tr>
# <tr><td>train_ray_tune_71ab8_00016</td><td>TERMINATED</td><td>10.47.0.57:1134076</td><td style="text-align: right;">         127</td><td style="text-align: right;">0.000138625</td><td style="text-align: right;">  0.129834</td><td style="text-align: right;">     5</td><td style="text-align: right;">         98.7499</td><td style="text-align: right;">    0.1051</td></tr>
# <tr><td>train_ray_tune_71ab8_00017</td><td>TERMINATED</td><td>10.47.0.57:1134077</td><td style="text-align: right;">          53</td><td style="text-align: right;">0.026005   </td><td style="text-align: right;">  0.193485</td><td style="text-align: right;">     5</td><td style="text-align: right;">        103.079 </td><td style="text-align: right;">    0.5429</td></tr>
# <tr><td>train_ray_tune_71ab8_00018</td><td>TERMINATED</td><td>10.47.0.57:1134078</td><td style="text-align: right;">          79</td><td style="text-align: right;">0.0135346  </td><td style
# 2023-07-21 08:28:48,841	INFO timeout.py:54 -- Reached timeout of 300 seconds. Stopping all trials.
# 2023-07-21 08:28:59,393	INFO tune.py:1148 -- Total run time: 310.97 seconds (300.46 seconds for the tuning loop).
# (train_ray_tune pid=1134070) Traceback (most recent call last):
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
# (train_ray_tune pid=1134070)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
# (train_ray_tune pid=1134070)     return method(__ray_actor, *args, **kwargs)
# (train_ray_tune pid=1134070)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 464, in _resume_span
# (train_ray_tune pid=1134070)     return method(self, *_args, **_kwargs)
# (train_ray_tune pid=1134070)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 372, in train
# (train_ray_tune pid=1134070)     result = self.step()
# (train_ray_tune pid=1134070)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 464, in _resume_span
# (train_ray_tune pid=1134070)     return method(self, *_args, **_kwargs)
# (train_ray_tune pid=1134070)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 389, in step
# (train_ray_tune pid=1134070)     result = self._results_queue.get(
# (train_ray_tune pid=1134070)   File "/usr/lib/python3.8/queue.py", line 179, in get
# (train_ray_tune pid=1134070)     self.not_empty.wait(remaining)
# (train_ray_tune pid=1134070)   File "/usr/lib/python3.8/threading.py", line 306, in wait
# (train_ray_tune pid=1134070)     gotit = waiter.acquire(True, timeout)
# (train_ray_tune pid=1134070)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/worker.py", line 776, in sigterm_handler
# (train_ray_tune pid=1134070)     sys.exit(1)
# (train_ray_tune pid=1134070) SystemExit: 1
# (train_ray_tune pid=1134070)
# (train_ray_tune pid=1134070) During handling of the above exception, another exception occurred:
# (train_ray_tune pid=1134070)
# (train_ray_tune pid=1134070) Traceback (most recent call last):
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1418, in ray._raylet.execute_task
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1501, in ray._raylet.execute_task
# (train_ray_tune pid=1134070)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/worker.py", line 569, in record_task_log_end
# (train_ray_tune pid=1134070)     self.core_worker.record_task_log_end(
# (train_ray_tune pid=1134070) AttributeError: 'Worker' object has no attribute 'core_worker'
# (train_ray_tune pid=1134070)
# (train_ray_tune pid=1134070) During handling of the above exception, another exception occurred:
# (train_ray_tune pid=1134070)
# (train_ray_tune pid=1134070) Traceback (most recent call last):
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1787, in ray._raylet.task_execution_handler
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1684, in ray._raylet.execute_task_with_cancellation_handler
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1366, in ray._raylet.execute_task
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1367, in ray._raylet.execute_task
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1583, in ray._raylet.execute_task
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 813, in ray._raylet.store_task_errors
# (train_ray_tune pid=1134070) AttributeError: 'Worker' object has no attribute 'core_worker'
# (train_ray_tune pid=1134070)
# (train_ray_tune pid=1134070) During handling of the above exception, another exception occurred:
# (train_ray_tune pid=1134070)
# (train_ray_tune pid=1134070) Traceback (most recent call last):
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1824, in ray._raylet.task_execution_handler
# (train_ray_tune pid=1134070)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/utils.py", line 174, in push_error_to_driver
# (train_ray_tune pid=1134070)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (train_ray_tune pid=1134070) AttributeError: 'Worker' object has no attribute 'core_worker'
# (train_ray_tune pid=1134070) Exception ignored in: 'ray._raylet.task_execution_handler'
# (train_ray_tune pid=1134070) Traceback (most recent call last):
# (train_ray_tune pid=1134070)   File "python/ray/_raylet.pyx", line 1824, in ray._raylet.task_execution_handler
# (train_ray_tune pid=1134070)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/utils.py", line 174, in push_error_to_driver
# (train_ray_tune pid=1134070)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (train_ray_tune pid=1134070) AttributeError: 'Worker' object has no attribute 'core_worker'
# 2023-07-21 08:28:59,567	WARNING experiment_analysis.py:916 -- Failed to read the results for 67 trials:
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00138_138_batch_size=123,lr=0.0001,momentum=0.3788_2023-07-21_08-25-45
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00139_139_batch_size=30,lr=0.0648,momentum=0.3449_2023-07-21_08-25-47
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00140_140_batch_size=78,lr=0.0001,momentum=0.2104_2023-07-21_08-25-52
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00176_176_batch_size=43,lr=0.0006,momentum=0.3516_2023-07-21_08-27-23
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00177_177_batch_size=56,lr=0.0006,momentum=0.7763_2023-07-21_08-27-23
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00178_178_batch_size=28,lr=0.0001,momentum=0.9114_2023-07-21_08-27-24
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00179_179_batch_size=19,lr=0.0417,momentum=0.8074_2023-07-21_08-27-26
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00180_180_batch_size=32,lr=0.0002,momentum=0.1343_2023-07-21_08-27-30
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00181_181_batch_size=41,lr=0.0110,momentum=0.4503_2023-07-21_08-27-31
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00182_182_batch_size=49,lr=0.0001,momentum=0.4149_2023-07-21_08-27-36
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00183_183_batch_size=53,lr=0.0006,momentum=0.7801_2023-07-21_08-27-38
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00184_184_batch_size=111,lr=0.0006,momentum=0.7629_2023-07-21_08-27-39
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00185_185_batch_size=33,lr=0.0001,momentum=0.8057_2023-07-21_08-27-43
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00186_186_batch_size=63,lr=0.0001,momentum=0.1952_2023-07-21_08-27-44
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00187_187_batch_size=44,lr=0.0572,momentum=0.3623_2023-07-21_08-27-47
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00188_188_batch_size=33,lr=0.0000,momentum=0.7739_2023-07-21_08-27-48
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00189_189_batch_size=90,lr=0.0684,momentum=0.1544_2023-07-21_08-27-49
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00190_190_batch_size=12,lr=0.0001,momentum=0.4684_2023-07-21_08-28-27
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00191_191_batch_size=126,lr=0.0000,momentum=0.1920_2023-07-21_08-28-31
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00192_192_batch_size=8,lr=0.0000,momentum=0.5099_2023-07-21_08-28-32
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00193_193_batch_size=22,lr=0.0001,momentum=0.2164_2023-07-21_08-28-35
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00194_194_batch_size=55,lr=0.0086,momentum=0.5836_2023-07-21_08-28-36
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00195_195_batch_size=35,lr=0.0004,momentum=0.8821_2023-07-21_08-28-41
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00196_196_batch_size=62,lr=0.0006,momentum=0.5330_2023-07-21_08-28-42
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00197_197_batch_size=23,lr=0.0094,momentum=0.7902_2023-07-21_08-28-44
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00198_198_batch_size=71,lr=0.0003,momentum=0.4579_2023-07-21_08-28-45
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00199_199_batch_size=36,lr=0.0041,momentum=0.9652_2023-07-21_08-28-45
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00200_200_batch_size=72,lr=0.0112,momentum=0.8138_2023-07-21_08-28-46
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00201_201_batch_size=120,lr=0.0017,momentum=0.6206_2023-07-21_08-28-46
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00202_202_batch_size=71,lr=0.0000,momentum=0.8069_2023-07-21_08-28-47
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00203_203_batch_size=69,lr=0.0100,momentum=0.2065_2023-07-21_08-28-47
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_08-23-46/train_ray_tune_71ab8_00204_204_batch_size=125,lr=0.0001,momentum=0.2077_2023-07-21_08-28-48

# %%
print("Best config is:", results.get_best_result().config)
print("Best test_acc is:", results.get_best_result().metrics["test_acc"])
# Out:
# Best config is: {'batch_size': 5, 'lr': 0.009555123918268555, 'momentum': 0.18686923960135482}
# Best test_acc is: 0.6143

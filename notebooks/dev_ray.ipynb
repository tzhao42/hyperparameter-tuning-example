# %% [markdown]
# # Hyperparameter Tuning with `ray`

# %% [markdown]
# ## Basic training script
#
# Classify images from the CIFAR10 dataset. We look at the effect of batch size, learning rate, and momentum.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms

# %%
DATA_PATH = "/home/tzhao/Workspace/hyperparameter-tuning-example/data"
NUM_EPOCHS = 4
DEVICE = "cpu" # Ray is very picky with resource usage, so we will use cpu to simplify configs

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

def train(batch_size, lr, momentum, verbose=True, download=True):
    # Load dataset
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    trainset = torchvision.datasets.CIFAR10(root=DATA_PATH, train=True, download=download, transform=transform)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)

    testset = torchvision.datasets.CIFAR10(root=DATA_PATH, train=False, download=download, transform=transform)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

    # Load nn
    net = Net().to(DEVICE)

    # Load loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)
    
    # Train
    for epoch in range(NUM_EPOCHS):
        
        # Train single epoch
        for data in trainloader:
            inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
        
        # Test
        test_loss = 0
        total = 0
        correct = 0
        with torch.no_grad():
            for data in testloader:
                inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
                outputs = net(inputs)

                # Get test loss
                loss = criterion(outputs, labels)
                test_loss += loss.item()

                # Get test acc
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        test_acc = correct / total

        if verbose:
            print(f"Epoch {epoch}: Test loss: {test_loss:.2f}")
            print(f"Epoch {epoch}: Test acc: {test_acc:.2f}")

    if verbose:
        print("Training completed.")
        print(f"Final test loss: {test_loss:.2f}")
        print(f"Final test acc: {test_acc:.2f}")
    
    return test_acc

# %%
# train(batch_size=4, lr=0.001, momentum=0.9, download=False)

# %%
# train(batch_size=128, lr=0.001, momentum=0.9, download=False)

# %% [markdown]
# Increasing batch size seems to give us worse accuracy, but is desirable because it runs faster. Can we get the bet of both worlds with hyperparameter tuning?

# %% [markdown]
# ## Hyperparameter tuning with `ray`

# %%
from ray import tune
from ray.air import session

# %%
def train_ray_tune(config):

    ###########################################
    ##### RAY TUNE: Initialize parameters #####
    ###########################################
    
    batch_size=config["batch_size"]
    lr=config["lr"]
    momentum=config["momentum"]
    verbose = False
    download = False

    ###########################################
    ###########################################
    ###########################################

    # Load dataset
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    trainset = torchvision.datasets.CIFAR10(root=DATA_PATH, train=True, download=download, transform=transform)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)

    testset = torchvision.datasets.CIFAR10(root=DATA_PATH, train=False, download=download, transform=transform)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

    # Load nn
    net = Net().to(DEVICE)

    # Load loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)
    
    # Train
    for epoch in range(NUM_EPOCHS):
        
        # Train single epoch
        for data in trainloader:
            inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
        
        # Test
        test_loss = 0
        total = 0
        correct = 0
        with torch.no_grad():
            for data in testloader:
                inputs, labels = data[0].to(DEVICE), data[1].to(DEVICE)
                outputs = net(inputs)

                # Get test loss
                loss = criterion(outputs, labels)
                test_loss += loss.item()

                # Get test acc
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        test_acc = correct / total

        if verbose:
            print(f"Epoch {epoch}: Test loss: {test_loss:.2f}")
            print(f"Epoch {epoch}: Test acc: {test_acc:.2f}")

        #########################################################
        ##### RAY TUNE: Report test loss and handle pruning #####
        #########################################################

        session.report({"test_acc": test_acc})

        #########################################################
        #########################################################
        #########################################################

    if verbose:
        print("Training completed.")
        print(f"Final test loss: {test_loss:.2f}")
        print(f"Final test acc: {test_acc:.2f}")
    
    return {"test_acc" : test_acc}

# %%
search_space = {
    "batch_size" : tune.randint(4,128),
    "lr": tune.loguniform(1e-5, 1e-1),
    "momentum": tune.uniform(0.1, 0.99),
}

tuner = tune.Tuner(
    train_ray_tune,
    tune_config=tune.TuneConfig(
        metric="test_acc",
        mode="max",
        num_samples=-1, # No limit to number of samples
        time_budget_s=300, # Limit time budget to 5 mins
    ),
    param_space=search_space,
)
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023
td><td style="text-align: right;">          64</td><td style="text-align: right;">0.00143724 </td><td style
# 2023-07-21 05:46:18,667	INFO timeout.py:54 -- Reached timeout of 300 seconds. Stopping all trials.
# (train_ray_tune pid=1031832) Traceback (most recent call last):
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
# (train_ray_tune pid=1031832)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/function_manager.py", line 726, in actor_method_executor
# (train_ray_tune pid=1031832)     return method(__ray_actor, *args, **kwargs)
# (train_ray_tune pid=1031832)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 464, in _resume_span
# (train_ray_tune pid=1031832)     return method(self, *_args, **_kwargs)
# (train_ray_tune pid=1031832)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 372, in train
# (train_ray_tune pid=1031832)     result = self.step()
# (train_ray_tune pid=1031832)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 464, in _resume_span
# (train_ray_tune pid=1031832)     return method(self, *_args, **_kwargs)
# (train_ray_tune pid=1031832)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 389, in step
# (train_ray_tune pid=1031832)     result = self._results_queue.get(
# (train_ray_tune pid=1031832)   File "/usr/lib/python3.8/queue.py", line 179, in get
# (train_ray_tune pid=1031832)     self.not_empty.wait(remaining)
# (train_ray_tune pid=1031832)   File "/usr/lib/python3.8/threading.py", line 306, in wait
# (train_ray_tune pid=1031832)     gotit = waiter.acquire(True, timeout)
# (train_ray_tune pid=1031832)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/worker.py", line 776, in sigterm_handler
# (train_ray_tune pid=1031832)     sys.exit(1)
# (train_ray_tune pid=1031832) SystemExit: 1
# (train_ray_tune pid=1031832)
# (train_ray_tune pid=1031832) During handling of the above exception, another exception occurred:
# (train_ray_tune pid=1031832)
# (train_ray_tune pid=1031832) Traceback (most recent call last):
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1418, in ray._raylet.execute_task
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1501, in ray._raylet.execute_task
# (train_ray_tune pid=1031832)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/worker.py", line 569, in record_task_log_end
# (train_ray_tune pid=1031832)     self.core_worker.record_task_log_end(
# (train_ray_tune pid=1031832) AttributeError: 'Worker' object has no attribute 'core_worker'
# (train_ray_tune pid=1031832)
# (train_ray_tune pid=1031832) During handling of the above exception, another exception occurred:
# (train_ray_tune pid=1031832)
# (train_ray_tune pid=1031832) Traceback (most recent call last):
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1787, in ray._raylet.task_execution_handler
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1684, in ray._raylet.execute_task_with_cancellation_handler
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1366, in ray._raylet.execute_task
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1367, in ray._raylet.execute_task
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1583, in ray._raylet.execute_task
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 813, in ray._raylet.store_task_errors
# (train_ray_tune pid=1031832) AttributeError: 'Worker' object has no attribute 'core_worker'
# (train_ray_tune pid=1031832)
# (train_ray_tune pid=1031832) During handling of the above exception, another exception occurred:
# (train_ray_tune pid=1031832)
# (train_ray_tune pid=1031832) Traceback (most recent call last):
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1824, in ray._raylet.task_execution_handler
# (train_ray_tune pid=1031832)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/utils.py", line 174, in push_error_to_driver
# (train_ray_tune pid=1031832)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (train_ray_tune pid=1031832) AttributeError: 'Worker' object has no attribute 'core_worker'
# (train_ray_tune pid=1031832) Exception ignored in: 'ray._raylet.task_execution_handler'
# (train_ray_tune pid=1031832) Traceback (most recent call last):
# (train_ray_tune pid=1031832)   File "python/ray/_raylet.pyx", line 1824, in ray._raylet.task_execution_handler
# (train_ray_tune pid=1031832)   File "/home/tzhao/Workspace/hyperparameter-tuning-example/env_ray/lib/python3.8/site-packages/ray/_private/utils.py", line 174, in push_error_to_driver
# (train_ray_tune pid=1031832)     worker.core_worker.push_error(job_id, error_type, message, time.time())
# (train_ray_tune pid=1031832) AttributeError: 'Worker' object has no attribute 'core_worker'
# 2023-07-21 05:46:29,029	INFO tune.py:1148 -- Total run time: 310.73 seconds (300.39 seconds for the tuning loop).
# 2023-07-21 05:46:29,191	WARNING experiment_analysis.py:916 -- Failed to read the results for 61 trials:
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00149_149_batch_size=32,lr=0.0005,momentum=0.3816_2023-07-21_05-44-52
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00150_150_batch_size=8,lr=0.0916,momentum=0.5537_2023-07-21_05-45-00
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00151_151_batch_size=2,lr=0.0000,momentum=0.6851_2023-07-21_05-45-03
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00152_152_batch_size=16,lr=0.0411,momentum=0.3697_2023-07-21_05-45-03
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00153_153_batch_size=16,lr=0.0002,momentum=0.8981_2023-07-21_05-45-06
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00154_154_batch_size=64,lr=0.0214,momentum=0.7218_2023-07-21_05-45-06
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00155_155_batch_size=8,lr=0.0065,momentum=0.2654_2023-07-21_05-45-07
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00156_156_batch_size=16,lr=0.0113,momentum=0.6584_2023-07-21_05-45-08
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00157_157_batch_size=32,lr=0.0001,momentum=0.4428_2023-07-21_05-45-16
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00158_158_batch_size=8,lr=0.0898,momentum=0.3876_2023-07-21_05-45-28
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00159_159_batch_size=2,lr=0.0008,momentum=0.2036_2023-07-21_05-45-29
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00160_160_batch_size=16,lr=0.0004,momentum=0.2336_2023-07-21_05-45-30
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00161_161_batch_size=2,lr=0.0361,momentum=0.3886_2023-07-21_05-45-30
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00162_162_batch_size=8,lr=0.0003,momentum=0.7882_2023-07-21_05-45-30
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00163_163_batch_size=16,lr=0.0000,momentum=0.8014_2023-07-21_05-45-30
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00164_164_batch_size=32,lr=0.0007,momentum=0.4097_2023-07-21_05-45-30
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00165_165_batch_size=4,lr=0.0000,momentum=0.2197_2023-07-21_05-45-44
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00166_166_batch_size=8,lr=0.0994,momentum=0.3170_2023-07-21_05-45-46
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00167_167_batch_size=16,lr=0.0002,momentum=0.2669_2023-07-21_05-45-47
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00168_168_batch_size=128,lr=0.0281,momentum=0.3022_2023-07-21_05-45-47
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00169_169_batch_size=16,lr=0.0000,momentum=0.1086_2023-07-21_05-45-48
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00170_170_batch_size=8,lr=0.0001,momentum=0.8021_2023-07-21_05-45-53
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00171_171_batch_size=32,lr=0.0000,momentum=0.4279_2023-07-21_05-45-54
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00172_172_batch_size=128,lr=0.0004,momentum=0.5952_2023-07-21_05-45-55
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00173_173_batch_size=8,lr=0.0337,momentum=0.8048_2023-07-21_05-45-57
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00174_174_batch_size=64,lr=0.0003,momentum=0.1262_2023-07-21_05-46-05
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00175_175_batch_size=2,lr=0.0000,momentum=0.6175_2023-07-21_05-46-06
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00176_176_batch_size=2,lr=0.0001,momentum=0.3542_2023-07-21_05-46-11
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00177_177_batch_size=128,lr=0.0020,momentum=0.7438_2023-07-21_05-46-12
# - /home/tzhao/ray_results/train_ray_tune_2023-07-21_05-41-15/train_ray_tune_be24f_00178_178_batch_size=32,lr=0.0480,momentum=0.1963_2023-07-21_05-46-16
# Best config is: {'batch_size': 64, 'lr': 0.024964308064702182, 'momentum': 0.8850857682485122}

# %%
print("Best config is:", results.get_best_result().config)
print("Best test_acc is:", results.get_best_result().metrics["test_acc"])
# Out:
# Best config is: {'batch_size': 64, 'lr': 0.024964308064702182, 'momentum': 0.8850857682485122}
# Best test_acc is: 0.605
